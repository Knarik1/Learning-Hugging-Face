# %% [markdown]
# # Contents

# %% [markdown]
# <img src='./assets/sec_6_1.png' align='left'>

# %% [markdown]
# * Task -> NER
# * Model -> XLM-R

# %% [markdown]
# ## 1. The Dataset

# %% [markdown]
# * Cross-lingual TRansfer Evaluation of Multilingual Encoders (XTREME) benchmark called Wikiann or PAN-X
# * This dataset consists of Wikipedia articles in 40 languages
# * annotated with LOC (location), PER (person) and ORG (organization) tags in the “inside-outside-beginning” (IOB2) format

# %% [markdown]
# <img src='./assets/xtreme_score.png'>

# %%
from datasets import load_dataset

# %%
dataset = load_dataset('xtreme', 'PAN-X.de', data_dir='./data')
# Out:
# Using custom data configuration PAN-X.de-data_dir=.%2Fdata
# Reusing dataset xtreme (/home/qnarik/.cache/huggingface/datasets/xtreme/PAN-X.de-data_dir=.%2Fdata/1.0.0/fb182342ff5c7a211ebf678cde070463acd29524b30b87f8f38c617948c2826a)
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
from datasets import DatasetDict
from collections import defaultdict

# %%
langs = ["de", "fr", "it", "en"]
fracs = [0.629, 0.229, 0.084, 0.059]

# %%
panx_ch = defaultdict(DatasetDict)

# %%
for lang, frac in zip(langs, fracs):
    ds = load_dataset("xtreme", f"PAN-X.{lang}", data_dir="data")
    for split in ds.keys():
        # shuffle and downsample each split according to spoken proportion
        panx_ch[lang][split] = ds[split].shuffle(seed=0).select(range(0, int(frac * ds[split].num_rows)))
# Out:
# Using custom data configuration PAN-X.de-data_dir=data
# Reusing dataset xtreme (/home/qnarik/.cache/huggingface/datasets/xtreme/PAN-X.de-data_dir=data/1.0.0/fb182342ff5c7a211ebf678cde070463acd29524b30b87f8f38c617948c2826a)
#   0%|          | 0/3 [00:00<?, ?it/s]
# Loading cached shuffled indices for dataset at /home/qnarik/.cache/huggingface/datasets/xtreme/PAN-X.de-data_dir=data/1.0.0/fb182342ff5c7a211ebf678cde070463acd29524b30b87f8f38c617948c2826a/cache-f0325a0542ae1c71.arrow
# Loading cached shuffled indices for dataset at /home/qnarik/.cache/huggingface/datasets/xtreme/PAN-X.de-data_dir=data/1.0.0/fb182342ff5c7a211ebf678cde070463acd29524b30b87f8f38c617948c2826a/cache-195f499064397123.arrow
# Loading cached shuffled indices for dataset at /home/qnarik/.cache/huggingface/datasets/xtreme/PAN-X.de-data_dir=data/1.0.0/fb182342ff5c7a211ebf678cde070463acd29524b30b87f8f38c617948c2826a/cache-5b9373e77997cb9c.arrow
# Using custom data configuration PAN-X.fr-data_dir=data
# ...

# %%
panx_ch
# Out:
# defaultdict(datasets.dataset_dict.DatasetDict,
#             {'de': DatasetDict({
#                  validation: Dataset({
#                      features: ['tokens', 'ner_tags', 'langs'],
#                      num_rows: 6290
#                  })
#                  test: Dataset({
#                      features: ['tokens', 'ner_tags', 'langs'],
#                      num_rows: 6290
#                  })
#                  train: Dataset({
#                      features: ['tokens', 'ner_tags', 'langs'],
#                      num_rows: 12580
#                  })
#              }),
#              'fr': DatasetDict({
#                  validation: Dataset({
#                      features: ['tokens', 'ner_tags', 'langs'],
#                      num_rows: 2290
#                  })
#                  test: Dataset({
#                      features: ['tokens', 'ner_tags', 'langs'],
#                      num_rows: 2290
#                  })
#                  train: Dataset({
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns=langs)

# %%
counts = [panx_ch[lang]['train'].num_rows for lang in langs]

# %%
counts
# Out:
# [12580, 4580, 1680, 1180]

# %%
df.loc[0] = counts

# %%
df.head()
# Out:
#       de    fr    it    en
# 0  12580  4580  1680  1180

# %% [markdown]
# or

# %%
pd.DataFrame({lang: [panx_ch[lang]['train'].num_rows] for lang in langs})
# Out:
#       de    fr    it    en
# 0  12580  4580  1680  1180

# %%
exp = panx_ch['de']['train'][1]

# %%
exp
# Out:
# {'tokens': ['Sie',
#   'geht',
#   'hinter',
#   'Walluf',
#   'nahtlos',
#   'in',
#   'die',
#   'Bundesautobahn',
#   '66',
#   'über',
#   '.'],
#  'ner_tags': [0, 0, 0, 3, 0, 0, 0, 3, 4, 0, 0],
#  'langs': ['de', 'de', 'de', 'de', 'de', 'de', 'de', 'de', 'de', 'de', 'de']}

# %%
panx_ch['de']['train']['ner_tags'][1]
# Out:
# [0, 0, 0, 3, 0, 0, 0, 3, 4, 0, 0]

# %%
panx_ch['de']['train']['tokens'][1]
# Out:
# ['Sie',
#  'geht',
#  'hinter',
#  'Walluf',
#  'nahtlos',
#  'in',
#  'die',
#  'Bundesautobahn',
#  '66',
#  'über',
#  '.']

# %%
tags = panx_ch['de']['train'].features['ner_tags'].feature
tags
# Out:
# ClassLabel(num_classes=7, names=['O', 'B-PER', 'I-PER', 'B-ORG', 'I-ORG', 'B-LOC', 'I-LOC'], names_file=None, id=None)

# %%
tags.str2int("I-ORG")
# Out:
# 4

# %%
tags.int2str(4)
# Out:
# 'I-ORG'

# %%
def create_tag_names(batch):
    return {"ner_tags_str": [tags.int2str(idx) for idx in batch["ner_tags"]]}

# %%
panx_de = panx_ch["de"].map(create_tag_names)
# Out:
# Loading cached processed dataset at /home/qnarik/.cache/huggingface/datasets/xtreme/PAN-X.de-data_dir=data/1.0.0/fb182342ff5c7a211ebf678cde070463acd29524b30b87f8f38c617948c2826a/cache-37f7e374deab7500.arrow
# Loading cached processed dataset at /home/qnarik/.cache/huggingface/datasets/xtreme/PAN-X.de-data_dir=data/1.0.0/fb182342ff5c7a211ebf678cde070463acd29524b30b87f8f38c617948c2826a/cache-178a406412aaadc4.arrow
# Loading cached processed dataset at /home/qnarik/.cache/huggingface/datasets/xtreme/PAN-X.de-data_dir=data/1.0.0/fb182342ff5c7a211ebf678cde070463acd29524b30b87f8f38c617948c2826a/cache-dda976c881c1fa62.arrow

# %%
de_example = panx_de["train"][0]
df = pd.DataFrame([de_example["tokens"], de_example["ner_tags_str"]],
['Tokens', 'Tags'])

# %%
df.head()
# Out:
#            0           1   2    3         4      5   6    7           8   \
# Tokens  2.000  Einwohnern  an  der  Danziger  Bucht  in  der  polnischen
# Tags        O           O   O    O     B-LOC  I-LOC   O    O       B-LOC
#
#                   9        10 11
# Tokens  Woiwodschaft  Pommern  .
# Tags           B-LOC    I-LOC  O

# %%
from itertools import chain
from collections import Counter

split2freqs = {}

for split in panx_de.keys():
    tag_names = []
    for row in panx_de[split]["ner_tags_str"]:
        tag_names.append([t.split("-")[1] for t in row if t.startswith("B")])
        split2freqs[split] = Counter(chain.from_iterable(tag_names))
    
pd.DataFrame.from_dict(split2freqs, orient="index")
# Out:
#              ORG   LOC   PER
# validation  2683  3172  2893
# test        2573  3180  3071
# train       5366  6186  5810

# %% [markdown]
# ## 2. Multilingual Transformers

# %% [markdown]
# To measure the progress of cross-lingual transfer for NER, the <b>CoNLL-2002</b> and <b>CoNLL-2003</b>. datasets are often
# used as a benchmark for English, Dutch, Spanish, and German. This benchmark consists of news articles annotated
# with the same LOC, PER, and ORG categories as PAN-X, but contains an additional <b>MISC</b> label for miscellaneous
# entities that do not belong to the previous three groups. Multilingual Transformer models are then evaluated in
# three different ways:

# %% [markdown]
# * Fine-tune on the English training data and then evaluate on each language’s test set.(en -> all)
# * Fine-tune and evaluate on monolingual training data to measure per-language performance.(en -> en)
# * Fine-tune on all the training data to evaluate multilingual learning.(all -> all)

# %% [markdown]
# #### mBERT
# Multilingual BERT (mBERT) 4 was developed by the authors of BERT from Google Research in 2018 and was <b>the
# first multilingual Transformer model</b>. It has the same architecture and training procedure as BERT, except that the
# pretraining corpus consists of Wikipedia articles from 104 languages. The tokenizer is also WordPiece, but the
# vocabulary is learnt from the whole corpus so that the model can share embeddings across languages.
# To handle the fact that each language’s Wikipedia dump can vary greatly in size, the data for pretraining and
# learning the WordPiece vocabulary is weighted with an exponential smoothing function that down-samples high-
# resource languages like English and up-samples low-resource languages likes Burmese.

# %% [markdown]
# ##### XLM
# * 3 learning objectives, CLM, MLM, TLM
# * but instead of receiving complete sentences as input (in BERT), XLM receives sentences that can be truncated arbitrarily
# * no NSP
# * To increase the number of tokens associated with low-resource languages, the sentences are sampled from a monolingual corpus {C } according to the multinomial distribution
# * Byte-Pair-Encoding instead of WordPiece for tokenization, which the authors observe improves the alignment of the language embeddings across languages

# %% [markdown]
# ##### XLM-R
# * XLM-R drops the language embeddings used in XLM and uses SentencePiece 6 to tokenize the raw texts directly
# * XLM-R and RoBERTa -> the size of the respective vocabularies: 250,000 tokens versus 55,000

# %% [markdown]
# <img src='./assets/table_1.png'>

# %% [markdown]
# <img src='./assets/table_2.png'>

# %% [markdown]
# ## 3. Training a Named Entity Recognition Tagger

# %% [markdown]
# <img src='./assets/table_3.png'>

# %% [markdown]
# BERT and other encoder
# Transformers take a similar approach for NER, except that the representation of every input token is fed <b>into the
# same</b> fully-connected layer to output the entity of the token. For this reason, NER is often framed as a token
# classification task.

# %% [markdown]
# Fortunately, all this intuition from BERT carries over to XLM-R since the architecture is based on RoBERTa,
# which is identical to BERT! However, there are some slight differences, especially around the choice of tokenizer.

# %% [markdown]
# ## SentencePiece vs WordPiece Tokenization

# %%
text = "Jack Sparrow loves New York!"

# %%
from transformers import AutoTokenizer

# %%
bert_name = 'bert-base-cased'
xlmr_name = 'xlm-roberta-base'

# %%
bert_tokenizer = AutoTokenizer.from_pretrained(bert_name)

# %%
xmlr_tokenizer = AutoTokenizer.from_pretrained(xlmr_name)

# %%
bert_tokenizer.tokenize(text)
# Out:
# ['Jack', 'Spa', '##rrow', 'loves', 'New', 'York', '!']

# %%
bert_tokenizer.decode(bert_tokenizer(text).input_ids)
# Out:
# '[CLS] Jack Sparrow loves New York! [SEP]'

# %%
bert_tokenizer(text).tokens()
# Out:
# ['[CLS]', 'Jack', 'Spa', '##rrow', 'loves', 'New', 'York', '!', '[SEP]']

# %%
xmlr_tokenizer.tokenize(text)
# Out:
# ['▁Jack', '▁Spar', 'row', '▁love', 's', '▁New', '▁York', '!']

# %%
xmlr_tokenizer.decode(xmlr_tokenizer(text).input_ids)
# Out:
# '<s> Jack Sparrow loves New York!</s>'

# %%
xmlr_tokenizer(text).tokens()
# Out:
# ['<s>', '▁Jack', '▁Spar', 'row', '▁love', 's', '▁New', '▁York', '!', '</s>']

# %% [markdown]
# * Here we see that instead of the [CLS] and [SEP] tokens that BERT uses for sentence classification tasks, XLM-R uses \<s> and <\s> to denote the start and end of a sequence.
# * Another special feature of SentencePiece is that it treats raw text as a sequence of Unicode characters, with whitespace given the Unicode symbol U+2581 or _ character. By assigning a special symbol for whitespace, SentencePiece is able to detokenize a sequence without ambiguities. In our example above, we can see that WordPiece has lost the information that there is no whitespace between “York” and “!”. <b>By contrast, SentencePiece preserves the whitespace</b> in the tokenized text so we can convert back to the raw text without ambiguit

# %% [markdown]
# ## 4. The Anatomy of the Transformers Model Class

# %% [markdown]
# <img src='./assets/table_4.png'>

# %%
from transformers import (AutoModel, 
                          BertModel, 
                          BertForPreTraining, 
                          BertLMHeadModel, 
                          BertForMaskedLM, 
                          BertForNextSentencePrediction, 
                          BertForSequenceClassification,
                          BertForMultipleChoice,
                          BertForTokenClassification,
                          BertForQuestionAnswering,
                         )

# %%
bert_name
# Out:
# 'bert-base-cased'

# %%
auto_model = AutoModel.from_pretrained(bert_name)
bert_model = BertModel.from_pretrained(bert_name)
pretained_model = BertForPreTraining.from_pretrained(bert_name)
# Out:
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
lmhead_model = BertLMHeadModel.from_pretrained(bert_name)
masked_model = BertForMaskedLM.from_pretrained(bert_name)
nsp_model = BertForNextSentencePrediction.from_pretrained(bert_name)
# Out:
# If you want to use `BertLMHeadModel` as a standalone, add `is_decoder=True.`
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertLMHeadModel: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertLMHeadModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertLMHeadModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# ...

# %%
clf_model = BertForSequenceClassification.from_pretrained(bert_name)
multichoise_model = BertForMultipleChoice.from_pretrained(bert_name)
tokenclf_model = BertForTokenClassification.from_pretrained(bert_name)
qa_model = BertForQuestionAnswering.from_pretrained(bert_name)
# Out:
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
# bert base is with POOLER block (dense_768 + tanh)
auto_model
# Out:
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(28996, 768, padding_idx=0)
#     (position_embeddings): Embedding(512, 768)
#     (token_type_embeddings): Embedding(2, 768)
#     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
# ...

# %%
# bert base is with POOLER block (dense_768 + tanh), 
# the same as AutoModel
bert_model
# Out:
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(28996, 768, padding_idx=0)
#     (position_embeddings): Embedding(512, 768)
#     (token_type_embeddings): Embedding(2, 768)
#     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
# ...

# %%
# bert base is with POOLER block (dense_768 + tanh)
# +
# cls layer - > BertPreTrainingHeads
pretained_model
# Out:
# BertForPreTraining(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(28996, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
# ...

# %%
# bert base No Pooler
# +
# cls layer - > BertOnlyMLMHead
lmhead_model
# Out:
# BertLMHeadModel(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(28996, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
# ...

# %% [markdown]
# BertForPreTraining VS BertLMHeadModel

# %% [markdown]
# <img src='./assets/compare_1.png'>

# %%
# bert base No Pooler
# +
# cls layer - > BertOnlyMLMHead
# the same as BertLMHeadModel, (BertForMaskedLM = BertLMHeadModel)
masked_model
# Out:
# BertForMaskedLM(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(28996, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
# ...

# %%
# bert base + Pooler
# +
# cls layer - > BertOnlyNSPHead
nsp_model
# Out:
# BertForNextSentencePrediction(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(28996, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
# ...

# %%
# bert base + Pooler
# +
# cls layer - > dropout + linear
clf_model
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(28996, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
# ...

# %%
# bert base + Pooler
# +
# cls layer - > dropout + linear
multichoise_model
# Out:
# BertForMultipleChoice(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(28996, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
# ...

# %%
# bert base No Pooler
# +
# cls layer - > dropout + linear
tokenclf_model
# Out:
# BertForTokenClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(28996, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
# ...

# %%
# bert base No Pooler
# +
# cls layer - > linear
qa_model
# Out:
# BertForQuestionAnswering(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(28996, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
# ...

# %% [markdown]
# Since
# <b>XLM-R uses the same model architecture as RoBERTa</b>, we will use RoBERTa as the base model, but augmented
# with settings specific to XLM-R.

# %%
import torch.nn as nn
from transformers import XLMRobertaConfig
from transformers.models.roberta.modeling_roberta import RobertaModel, RobertaPreTrainedModel
from transformers.modeling_outputs import TokenClassifierOutput

# %%
class XLMRobertaForTokenClassification(RobertaPreTrainedModel):
    config_class = XLMRobertaConfig
    
    def __init__(self, config):
        super().__init__(config)
        
        self.num_labels = config.num_labels
        self.model = RobertaModel(config, add_pooling_layer=False)
        self.dropout = nn.Droupout(config.hidden_dropout_prob)
        self.cassifier = nn.Linear(input_features=config.hidden_size, output_features=config.num_labels)
        self.init_weights()
        
    def forward(self, input_ids=None, attention_mask=None,
        token_type_ids=None, labels=None, **kwargs):
        pass

# %%
    def forward(self, input_ids=None, attention_mask=None, token_type_ids=None, labels=None, **kwargs):
        outputs = self.model(input_ids, attention_mask=attention_mask, token_type_ids=token_type_ids, **kwargs)
        sequence_output = outputs[0]
        sequence_output = self.dropout(sequence_output)
        logits = self.classifier(sequence_output)
        
        loss = None
        if labels:
            loss_fn = nn.CrossEntropyLoss()
            loss = loss_fn(logits.view(-1, self.num_labels), labels.view(-1))
        
        return TokenClassifierOutput(loss=loss, logits=logits, hidden_states = outputs.hidden_states, attentions=outputs.attentions)

# %%
XLMRobertaForTokenClassification.forward = forward

# %% [markdown]
# ## 5. Error Analysis

# %% [markdown]
# ## 6. Evaluating Cross-Lingual Transfer

# %% [markdown]
# ## 7. When Does Zero-Shot Transfer Make Sense?

# %% [markdown]
# ## 8. Fine-tuning on Multiple Languages at Once

# %% [markdown]
# ## 9. Building a Pipeline for Inference

# %% [markdown]
# ## Conclusion
